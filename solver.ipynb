# %%
import os
# print(os.getcwd())

os.chdir('/Users/ayman/Desktop/workspace/cubeAI')

from cubeai.cube.moves import Cube
from cubeai.test.testing_functions import do_scramble, sanitize, solved_cube, iterate_through_scrambles_for_testing

# %%
_cube = do_scramble(['R2', 'Fp', 'Dp', 'B', 'D2', 'Lp', 'Fp', 'D', 'F', 'R2', 'D2', 'B'])

_cube.cube_state
_cube.combo()

# _cube.seven_type_cross_solver()
# Out:
# [['_seven_type', 'orange', 'g', 'r'],
#  ['_one_type', 'orange', 'y', 'b'],
#  ['_top_type', 'yellow_b', 'b', 'g'],
#  ['bottum_type', 'white_r', 'r', 'o']]

# %%
_combo = _cube.combo()
_combo_list = []
for i in _combo:
    _combo_list.append(i[0])
print('_combo_list: ', _combo_list)
# Out:
# _combo_list:  ['_seven_type', '_one_type', '_top_type', 'bottum_type']

# %%
_cube.three_type_cross_solver()

# %%
def sanitize(moves):

    unique_list = []
    seen = set()

    if moves is not None:

        for sublist in moves:
            cleaned_sublist = [item for item in sublist if item != 'I']
            cleaned_tuple = tuple(cleaned_sublist)
            if cleaned_tuple not in seen:
                unique_list.append(cleaned_sublist)
                seen.add(cleaned_tuple)

    else:
        pass
    return unique_list

# %% [markdown]
# ___________________

# %%
class TreeNode:
    def __init__(self, val):
        self.val = val
        self.children = []

# %% [markdown]
# __________________

# %%
solutions = []
def treeify(self, cur_moves):

    _combo_dict = {
    '_seven_type' : 'seven_type_cross_solver',
    '_three_type' : 'three_type_cross_solver',
    '_one_type' : 'one_type_cross_solver',
    '_top_type' : 'top_type_cross_solver',
    '_five_type' : 'five_type_cross_solver'
    }
    
    _combo = self.combo()
    _combo_list = []
    for i in _combo:
        _combo_list.append(i[0])

    level = []
    for _combo_type in _combo_list:
        if _combo_type != 'bottum_type':
            level.append(TreeNode(_combo_type))
    
    # print('combo types:', [[l.val, l.children] for l in level])
    # print('-----------')

    for node in level:
        node.children = getattr(self, _combo_dict[node.val])()
        node.children = sanitize(node.children)
        node.children = [TreeNode(tuple(c)) for c in node.children]

    _new_cubes = []
    for node in level:
        for c in node.children:
            # y=self
            _new_cube = do_scramble(c.val, self)
            # _new_cubes.append(_new_cube)
            c.children = [TreeNode(_new_cube)]
            _new_cube_combo = _new_cube.combo()
            _new_cube_combo_list = []
            for i in _new_cube_combo:
                _new_cube_combo_list.append(i[0])
            if _new_cube_combo_list.count('bottum_type') == 4:
                # solutions.append(cur_moves + [c.val])
                _all_moves = []
                for move_set in (cur_moves + [c.val]):
                    for sub_move in move_set:
                        _all_moves.append(sub_move)
                final_set_of_moves = _new_cube.bottum_type_cross_solver()
                if final_set_of_moves == None: # invesitage this
                    return
                solutions.append(_all_moves+final_set_of_moves[0]) # should we return solutions?
            else:
                _all_moves = []
                for move_set in (cur_moves + [c.val]):
                    for sub_move in move_set:
                        _all_moves.append(sub_move)
                if len(_all_moves) <= 6: 
                    treeify(_new_cube, cur_moves + [c.val])  # should we return solutions?

    # return _new_cubes

# %%
import random
moves = ['R', 'U', 'F', 'D', 'L', 'B', 'Rp', 'Up', 'Fp', 'Dp', 'Lp', 'Bp', 'R2', 'U2', 'F2', 'D2', 'L2', 'B2']
scramble = []
def generate_random_moves():
    scramble = []
    for move in range(20):
        mv = random.choice(moves)
        if move == 0:
            scramble.append(mv)
        elif move > 1 and mv[0] != scramble[-1][0]:
            scramble.append(mv)
        else:
            continue
    return scramble
do_these_moves = ['R','U2','Rp','U2','D2','Bp','F','Rp','U2','D','L','R','D2','Lp','F2','B2'] # this yeilded 8

# %%
xyz = []
for i in range(5):
    xyz.append(generate_random_moves())
xyz
# Out:
# [['D',
#   'Fp',
#   'B',
#   'R2',
#   'U2',
#   'F',
#   'Up',
#   'R2',
#   'Fp',
#   'Bp',
#   'Dp',
#   'R',
#   'B',
#   'D',
#   'L2',
#   'D'],
#  ['L2',
#   'Up',
#   'Lp',
#   'Dp',
#   'R',
#   'Fp',
#   'B',
#   'Rp',
#   'U2',
#   'B',
#   'U2',
#   'B',
#   'U2',
#   'Fp',
#   'D',
#   'Bp'],
#  ['Dp',
#   'Lp',
#   'U2',
#   'Dp',
#   'B2',
#   'D2',
#   'Rp',
#   'Bp',
#   'D',
#   'U2',
#   'Rp',
#   'Bp',
#   'Fp',
#   'B2',
#   'Lp',
#   'Fp'],
#  ['Lp',
#   'D2',
#   'R2',
#   'F2',
#   'R',
#   'Dp',
#   'Up',
#   'B2',
#   'U',
#   'F2',
#   'Lp',
#   'U',
#   'B2',
#   'U',
#   'Bp'],
#  ['R2',
#   'B2',
#   'U2',
#   'D',
#   'R2',
#   'F',
#   'R2',
#   'Dp',
#   'L2',
#   'R',
#   'L',
#   'D',
#   'L',
#   'R2']]

# %%
for i in iterate_through_scrambles_for_testing(xyz):
    treeify(i, [])
# Out:
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['F', 'Fp']]]
# [[['D2'], ['B', 'Bp']], [['I'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']], [['I'], ['R', 'Rp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# [[['I'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# not a bottum solver case
# not a bottum solver case
# not a bottum solver case
# [[['Dp'], ['R', 'Rp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['D2'], ['R', 'Rp']]]
# [[['D2'], ['R', 'Rp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['Dp'], ['R', 'Rp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']]]
# [[['D2'], ['R', 'Rp']]]
# [[['Dp'], ['R', 'Rp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']]]
# [[['D2'], ['R', 'Rp']]]
# [[['D2'], ['R', 'Rp']], [['D2'], ['R', 'Rp']]]
# [[['D'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['B', 'Bp']], [['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['B', 'Bp']], [['I'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['Dp'], ['R', 'Rp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['D2'], ['R', 'Rp']]]
# [[['D2'], ['R', 'Rp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['Dp'], ['R', 'Rp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']]]
# [[['D2'], ['R', 'Rp']]]
# [[['Dp'], ['R', 'Rp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']]]
# [[['D2'], ['R', 'Rp']]]
# [[['D2'], ['R', 'Rp']], [['D2'], ['R', 'Rp']]]
# [[['D'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['B', 'Bp']], [['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['B', 'Bp']], [['I'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D2'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['I'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['Dp'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['Dp'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['Dp'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['Dp'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['Dp'], ['B', 'Bp']]]
# [[['D2'], ['R', 'Rp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['Dp'], ['B', 'Bp']]]
# [[['Dp'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['D'], ['F', 'Fp']], [['D'], ['F', 'Fp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# not a bottum solver case
# not a bottum solver case
# [[['I'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# not a bottum solver case
# [[['I'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# not a bottum solver case
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['I'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']], [['I'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']], [['I'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# [[['Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['D'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# [[['Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['D'], ['F', 'Fp']], [['D'], ['F', 'Fp']]]
# [[['I'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# [[['D2'], ['R', 'Rp']]]
# [[['D2'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']], [['D', 'Dp'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']], [['D', 'Dp'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D2'], ['R', 'Rp']]]
# [[['D2'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']], [['D', 'Dp'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']], [['D', 'Dp'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['I'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']], [['I'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']], [['I'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# [[['Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['D'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# [[['Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['D'], ['F', 'Fp']], [['D'], ['F', 'Fp']]]
# [[['I'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# [[['D2'], ['R', 'Rp']]]
# [[['D2'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']], [['D', 'Dp'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']], [['D', 'Dp'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D2'], ['R', 'Rp']]]
# [[['D2'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']], [['D', 'Dp'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']], [['D', 'Dp'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D2'], ['R', 'Rp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['Dp'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']]]
# [[['Dp'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']]]
# [[['Dp'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['Dp'], ['B', 'Bp']], [['Dp'], ['B', 'Bp']]]
# [[['Dp'], ['F', 'Fp']]]
# [[['Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['L', 'Lp']]]
# [[['Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['F', 'Fp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['L', 'Lp']]]
# [[['Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['F', 'Fp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['L', 'Lp']]]
# [[['Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['F', 'Fp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# [[['Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['F', 'Fp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['F', 'Fp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['F', 'Fp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# [[['D', 'Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D'], ['F', 'Fp']], [['D'], ['F', 'Fp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['Dp'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['Dp'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']], [['Dp'], ['B', 'Bp']], [['Dp'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# not a bottum solver case
# not a bottum solver case
# [[['I'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# not a bottum solver case
# not a bottum solver case
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# not a bottum solver case
# not a bottum solver case
# [[['I'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# not a bottum solver case
# not a bottum solver case
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['Dp'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['Dp'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']], [['Dp'], ['B', 'Bp']], [['Dp'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D'], ['F', 'Fp']], [['D'], ['F', 'Fp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['Dp'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['Dp'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']], [['Dp'], ['B', 'Bp']], [['Dp'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# not a bottum solver case
# not a bottum solver case
# [[['I'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# not a bottum solver case
# not a bottum solver case
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# not a bottum solver case
# not a bottum solver case
# [[['I'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# not a bottum solver case
# not a bottum solver case
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['Dp'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['Dp'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']], [['Dp'], ['B', 'Bp']], [['Dp'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['F', 'Fp']]]
# [[['D2'], ['B', 'Bp']], [['I'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']], [['I'], ['R', 'Rp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['I'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# [[['Dp'], ['R', 'Rp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']]]
# [[['D2'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['Dp'], ['R', 'Rp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']]]
# [[['D2'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['Dp'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['Dp'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['Dp'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['D'], ['F', 'Fp']], [['D'], ['F', 'Fp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['Dp'], ['F', 'Fp']]]
# [[['Dp'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['L', 'Lp']]]
# [[['Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['F', 'Fp']]]
# [[['D', 'Dp'], ['L', 'Lp']]]
# [[['Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['F', 'Fp']]]
# [[['D', 'Dp'], ['L', 'Lp']]]
# [[['Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['F', 'Fp']]]
# [[['D'], ['B', 'Bp']]]
# [[['Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['F', 'Fp']]]
# [[['D'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['F', 'Fp']]]
# [[['D'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['F', 'Fp']]]
# [[['D'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D'], ['L', 'Lp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D'], ['L', 'Lp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['F', 'Fp']]]
# [[['D2'], ['B', 'Bp']], [['I'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']], [['I'], ['R', 'Rp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['Dp'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['Dp'], ['F', 'Fp']]]
# [[['I'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['F', 'Fp']]]
# [[['D2'], ['R', 'Rp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D'], ['L', 'Lp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['F', 'Fp']]]
# [[['I'], ['F', 'Fp']]]
# [[['I'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']]]
# [[['D'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']]]
# [[['D'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['Dp'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D2'], ['F', 'Fp']]]
# [[['D2'], ['F', 'Fp']]]
# [[['D2'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['Dp'], ['F', 'Fp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# [[['I'], ['F', 'Fp']]]
# [[['D', 'Dp'], ['F', 'Fp']]]
# [[['D', 'Dp'], ['F', 'Fp']]]
# [[['I'], ['F', 'Fp']]]
# [[['I'], ['F', 'Fp']]]
# [[['I'], ['F', 'Fp']]]
# [[['D', 'Dp'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['D'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['Dp'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['Dp'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']], [['Dp'], ['B', 'Bp']], [['Dp'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# not a bottum solver case
# not a bottum solver case
# [[['I'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# not a bottum solver case
# not a bottum solver case
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# not a bottum solver case
# not a bottum solver case
# [[['I'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# not a bottum solver case
# not a bottum solver case
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['Dp'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['Dp'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']], [['Dp'], ['B', 'Bp']], [['Dp'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['F', 'Fp']]]
# [[['D2'], ['R', 'Rp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['Dp'], ['L', 'Lp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D'], ['F', 'Fp']], [['D'], ['F', 'Fp']]]
# [[['D'], ['F', 'Fp']], [['D'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']], [['Dp'], ['F', 'Fp']]]
# [[['I'], ['F', 'Fp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['I'], ['F', 'Fp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['I'], ['F', 'Fp']]]
# [[['I'], ['F', 'Fp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['I'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']], [['Dp'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']], [['Dp'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']]]
# [[['D2'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']], [['Dp'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']], [['Dp'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']]]
# [[['D2'], ['F', 'Fp']]]
# [[['D'], ['F', 'Fp']]]
# [[['D'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']]]
# [[['D2'], ['F', 'Fp']]]
# [[['D'], ['F', 'Fp']]]
# [[['D'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D'], ['L', 'Lp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D'], ['L', 'Lp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['F', 'Fp']]]
# [[['D2'], ['B', 'Bp']], [['I'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']], [['I'], ['R', 'Rp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['R', 'Rp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['Dp'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['Dp'], ['F', 'Fp']]]
# [[['I'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['F', 'Fp']]]
# [[['D2'], ['R', 'Rp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D'], ['L', 'Lp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['F', 'Fp']]]
# [[['I'], ['F', 'Fp']]]
# [[['I'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']]]
# [[['D'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']]]
# [[['D'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D'], ['F', 'Fp']], [['D'], ['F', 'Fp']]]
# [[['D'], ['F', 'Fp']], [['D'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']], [['Dp'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['D'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['D'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['Dp'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['Dp'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['Dp'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['Dp'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['Dp'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']], [['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['Dp'], ['B', 'Bp']], [['Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']]]
# [[['Dp'], ['B', 'Bp']], [['Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']]]
# [[['Dp'], ['F', 'Fp']], [['Dp'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']], [['Dp'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']], [['Dp'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']], [['Dp'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']]]
# [[['D'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D2'], ['F', 'Fp']]]
# [[['D2'], ['F', 'Fp']]]
# [[['D2'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['Dp'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['Dp'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D2'], ['F', 'Fp']]]
# [[['D2'], ['F', 'Fp']]]
# [[['D2'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D2'], ['F', 'Fp']], [['D2'], ['F', 'Fp']]]
# [[['D2'], ['F', 'Fp']], [['D2'], ['F', 'Fp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D2'], ['F', 'Fp']], [['D2'], ['F', 'Fp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D2'], ['F', 'Fp']]]
# [[['I'], ['F', 'Fp']]]
# [[['D2'], ['F', 'Fp']], [['D2'], ['F', 'Fp']]]
# [[['D2'], ['F', 'Fp']], [['D2'], ['F', 'Fp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D2'], ['F', 'Fp']], [['D2'], ['F', 'Fp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D2'], ['F', 'Fp']]]
# [[['I'], ['F', 'Fp']]]
# [[['D2'], ['F', 'Fp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['Dp'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D2'], ['F', 'Fp']]]
# [[['D2'], ['F', 'Fp']]]
# [[['D2'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['Dp'], ['F', 'Fp']], [['Dp'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']], [['Dp'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']], [['Dp'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']], [['Dp'], ['F', 'Fp']]]
# [[['Dp'], ['F', 'Fp']]]
# [[['D'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['D2'], ['F', 'Fp']]]
# [[['D2'], ['F', 'Fp']]]
# [[['D2'], ['F', 'Fp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['Dp'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']]]
# [[['D'], ['B', 'Bp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# [[['I'], ['R', 'Rp']]]
# not a bottum solver case
# not a bottum solver case
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# not a bottum solver case
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# not a bottum solver case
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# not a bottum solver case
# not a bottum solver case
# [[['D2'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['Dp'], ['B', 'Bp']], [['Dp'], ['B', 'Bp']], [['Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D2'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['D2'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['D2'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D2'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['D2'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['D2'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['D2'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D2'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['D2'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['D2'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['D2'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['D2'], ['L', 'Lp']], [['D2'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['D2'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D2'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['D2'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['D2'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['D2'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['D2'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# not a bottum solver case
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# not a bottum solver case
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# not a bottum solver case
# not a bottum solver case
# [[['D2'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D2'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['D2'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['D2'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['D2'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# not a bottum solver case
# not a bottum solver case
# [[['D2'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# not a bottum solver case
# [[['D2'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# not a bottum solver case
# not a bottum solver case
# not a bottum solver case
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# [[['D', 'Dp'], ['F', 'Fp']], [['I'], ['F', 'Fp']], [['I'], ['F', 'Fp']]]
# [[['D2'], ['L', 'Lp']], [['I'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']]]
# [[['D2'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['D2'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D2'], ['L', 'Lp']]]
# ...
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['R', 'Rp']], [['I'], ['R', 'Rp']]]
# [[['I'], ['F', 'Fp']]]
# [[['D', 'Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['F', 'Fp']]]
# [[['I'], ['F', 'Fp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['F', 'Fp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['L', 'Lp']]]
# [[['D', 'Dp'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# [[['D'], ['L', 'Lp']]]
# [[['Dp'], ['L', 'Lp']]]
# [[['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['L', 'Lp']]]
# [[['D', 'Dp'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# [[['D'], ['L', 'Lp']]]
# [[['Dp'], ['L', 'Lp']]]
# [[['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['L', 'Lp']]]
# [[['D', 'Dp'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# [[['D'], ['L', 'Lp']]]
# [[['Dp'], ['L', 'Lp']]]
# [[['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']]]
# [[['D2'], ['B', 'Bp']]]
# [[['I'], ['F', 'Fp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['B', 'Bp']], [['I'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['F', 'Fp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['L', 'Lp']]]
# [[['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['L', 'Lp']]]
# [[['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['D', 'Dp'], ['L', 'Lp']]]
# [[['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['F', 'Fp']]]
# [[['I'], ['F', 'Fp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['D'], ['B', 'Bp']], [['D'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['L', 'Lp']], [['D', 'Dp'], ['L', 'Lp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]
# [[['I'], ['B', 'Bp']], [['D', 'Dp'], ['B', 'Bp']]]

# %%
_cube = do_scramble(['R2', 'Fp', 'Dp', 'B', 'D2', 'Lp', 'Fp', 'D', 'F', 'R2', 'D2', 'B'])
_cube = do_scramble(['R', 'D', 'U', 'Lp', 'R', 'R', 'U']) # look at last 18 move, why did it moess up bottum?
_cube = do_scramble(scramble)


treeify(_cube, [])

# %%
# import numpy as np
solns = [[len(mvs), mvs] for mvs in solutions]
sorted_solns = sorted(solns, key=lambda x: x[0])
sorted_solns
# Out:
# [[6, ['U2', 'Rp', 'D', 'L', 'F', 'D']],
#  [6, ['U2', 'Rp', 'D', 'L', 'F', 'D']],
#  [6, ['L', 'Fp', 'Dp', 'F', 'Rp', 'D2']],
#  [6, ['L', 'Fp', 'Dp', 'F', 'Rp', 'D2']],
#  [6, ['L', 'Fp', 'Dp', 'F', 'Rp', 'D2']],
#  [6, ['L', 'Fp', 'Dp', 'F', 'Rp', 'D2']],
#  [7, ['D', 'L', 'Dp', 'Rp', 'D', 'Fp', 'D']],
#  [7, ['D', 'L', 'Dp', 'Rp', 'D', 'Fp', 'D']],
#  [7, ['Lp', 'U2', 'Rp', 'Dp', 'B', 'Rp', 'Dp']],
#  [7, ['Lp', 'U2', 'Rp', 'Dp', 'Rp', 'B', 'Dp']],
#  [8, ['D', 'L', 'Fp', 'Dp', 'F', 'Rp', 'Fp', 'D2']],
#  [8, ['D', 'L', 'Fp', 'Dp', 'F', 'Rp', 'Fp', 'D2']],
#  [8, ['D', 'L', 'Fp', 'Dp', 'F', 'Rp', 'Fp', 'D2']],
#  [8, ['D', 'L', 'Fp', 'Dp', 'F', 'Rp', 'Fp', 'D2']],
#  [8, ['U2', 'Rp', 'D', 'F', 'Fp', 'L', 'F', 'D']],
#  [8, ['U2', 'Rp', 'D', 'F', 'Fp', 'L', 'F', 'D']],
#  [8, ['U2', 'Rp', 'D', 'F', 'Fp', 'L', 'F', 'D']],
#  [8, ['U2', 'Rp', 'D', 'F', 'Fp', 'L', 'F', 'D']],
#  [8, ['L', 'Rp', 'Fp', 'Dp', 'F', 'Dp', 'Fp', 'Dp']],
#  [8, ['L', 'Dp', 'Rp', 'D', 'Fp', 'Dp', 'F', 'D2']],
#  [8, ['L', 'D', 'Fp', 'D', 'F', 'D2', 'Rp', 'D2']],
#  [8, ['L', 'D', 'Fp', 'D', 'F', 'D2', 'Rp', 'D2']],
#  [8, ['L', 'Fp', 'Dp', 'Fp', 'F', 'F', 'Rp', 'D2']],
#  [8, ['L', 'Fp', 'Dp', 'Fp', 'F', 'F', 'Rp', 'D2']],
#  [8, ['L', 'Fp', 'Dp', 'Fp', 'Fp', 'Fp', 'Rp', 'D2']],
#  [8, ['L', 'Fp', 'Dp', 'Fp', 'Fp', 'Fp', 'Rp', 'D2']],
#  [8, ['L', 'Fp', 'F', 'Fp', 'Dp', 'F', 'Rp', 'D2']],
#  [8, ['L', 'Fp', 'F', 'Fp', 'Dp', 'F', 'Rp', 'D2']],
#  [8, ['L', 'Fp', 'F', 'Fp', 'Dp', 'F', 'Rp', 'D2']],
#  [8, ['L', 'Fp', 'F', 'Fp', 'Dp', 'F', 'Rp', 'D2']],
#  [8, ['L', 'Fp', 'Fp', 'F', 'Dp', 'F', 'Rp', 'D2']],
#  [8, ['L', 'Fp', 'Fp', 'F', 'Dp', 'F', 'Rp', 'D2']],
#  [8, ['L', 'Fp', 'Fp', 'F', 'Dp', 'F', 'Rp', 'D2']],
#  [8, ['L', 'Fp', 'Fp', 'F', 'Dp', 'F', 'Rp', 'D2']],
#  [8, ['L', 'Rp', 'Fp', 'Dp', 'F', 'Dp', 'Fp', 'Dp']],
#  [8, ['L', 'Dp', 'Rp', 'D', 'Fp', 'Dp', 'F', 'D2']],
#  [8, ['L', 'D', 'Fp', 'D', 'F', 'D2', 'Rp', 'D2']],
#  [8, ['L', 'D', 'Fp', 'D', 'F', 'D2', 'Rp', 'D2']],
#  [8, ['L', 'Fp', 'Dp', 'Fp', 'F', 'F', 'Rp', 'D2']],
#  [8, ['L', 'Fp', 'Dp', 'Fp', 'F', 'F', 'Rp', 'D2']],
#  [8, ['L', 'Fp', 'Dp', 'Fp', 'Fp', 'Fp', 'Rp', 'D2']],
#  [8, ['L', 'Fp', 'Dp', 'Fp', 'Fp', 'Fp', 'Rp', 'D2']],
#  [8, ['L', 'Fp', 'F', 'Fp', 'Dp', 'F', 'Rp', 'D2']],
#  [8, ['L', 'Fp', 'F', 'Fp', 'Dp', 'F', 'Rp', 'D2']],
#  [8, ['L', 'Fp', 'F', 'Fp', 'Dp', 'F', 'Rp', 'D2']],
#  [8, ['L', 'Fp', 'F', 'Fp', 'Dp', 'F', 'Rp', 'D2']],
#  [8, ['L', 'Fp', 'Fp', 'F', 'Dp', 'F', 'Rp', 'D2']],
#  [8, ['L', 'Fp', 'Fp', 'F', 'Dp', 'F', 'Rp', 'D2']],
#  [8, ['L', 'Fp', 'Fp', 'F', 'Dp', 'F', 'Rp', 'D2']],
#  [8, ['L', 'Fp', 'Fp', 'F', 'Dp', 'F', 'Rp', 'D2']],
#  [8, ['Lp', 'U', 'Dp', 'B', 'D', 'B', 'Rp', 'D2']],
#  [8, ['Lp', 'U', 'Dp', 'B', 'D', 'Rp', 'B', 'D2']],
#  [8, ['Lp', 'D2', 'Fp', 'L', 'R', 'D2', 'Lp', 'Rp']],
#  [8, ['D2', 'Lp', 'R', 'D2', 'L', 'D2', 'F', 'D2']],
#  [8, ['D2', 'Lp', 'R', 'F', 'F', 'Rp', 'Fp', 'D2']],
#  [8, ['D2', 'Lp', 'R', 'F', 'F', 'Rp', 'Fp', 'D2']],
#  [8, ['D2', 'Lp', 'R', 'D2', 'L', 'D2', 'F', 'D2']],
#  [8, ['D2', 'Lp', 'R', 'F', 'F', 'Rp', 'Fp', 'D2']],
#  [8, ['D2', 'Lp', 'R', 'F', 'F', 'Rp', 'Fp', 'D2']],
#  [8, ['L', 'U', 'B', 'D', 'B', 'D2', 'Bp', 'D']],
#  [8, ['Lp', 'D2', 'Fp', 'L', 'R', 'D2', 'Lp', 'Rp']],
#  [8, ['Up', 'D2', 'Rp', 'D', 'Rp', 'D', 'R', 'D']],
#  [8, ['D', 'F', 'F', 'D2', 'L', 'Dp', 'Lp', 'D2']],
#  [8, ['D', 'F', 'F', 'D2', 'L', 'Dp', 'Lp', 'D2']],
#  [8, ['D', 'Fp', 'Fp', 'D2', 'L', 'Dp', 'Lp', 'D2']],
#  [8, ['D', 'Fp', 'Fp', 'D2', 'L', 'Dp', 'Lp', 'D2']],
#  [8, ['R', 'U2', 'R', 'D2', 'R', 'D', 'R', 'Dp']],
#  [8, ['R', 'L', 'L', 'R', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['R', 'L', 'L', 'R', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['R', 'L', 'R', 'U2', 'L', 'D', 'L', 'D']],
#  [8, ['R', 'L', 'L', 'R', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['R', 'L', 'L', 'R', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['R', 'L', 'R', 'U2', 'L', 'D', 'L', 'D']],
#  [8, ['R', 'Lp', 'R', 'U2', 'Lp', 'D', 'Lp', 'D']],
#  [8, ['R', 'Lp', 'Lp', 'R', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['R', 'Lp', 'Lp', 'R', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['R', 'Lp', 'Lp', 'R', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['R', 'Lp', 'Lp', 'R', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['Rp', 'U2', 'Rp', 'D2', 'Rp', 'D', 'Rp', 'Dp']],
#  [8, ['Rp', 'L', 'L', 'Rp', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['Rp', 'L', 'L', 'Rp', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['Rp', 'L', 'L', 'Rp', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['Rp', 'L', 'L', 'Rp', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['Rp', 'L', 'Rp', 'U2', 'L', 'D', 'L', 'D']],
#  [8, ['Rp', 'Lp', 'Rp', 'U2', 'Lp', 'D', 'Lp', 'D']],
#  [8, ['Rp', 'Lp', 'Lp', 'Rp', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['Rp', 'Lp', 'Lp', 'Rp', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['Rp', 'Lp', 'Rp', 'U2', 'Lp', 'D', 'Lp', 'D']],
#  [8, ['Rp', 'Lp', 'Lp', 'Rp', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['Rp', 'Lp', 'Lp', 'Rp', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['L', 'U2', 'L', 'D2', 'L', 'Dp', 'Lp', 'D']],
#  [8, ['L', 'R', 'L', 'R', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['L', 'R', 'L', 'R', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['L', 'R', 'R', 'U2', 'L', 'D', 'L', 'D']],
#  [8, ['L', 'R', 'L', 'R', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['L', 'R', 'L', 'R', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['L', 'R', 'R', 'U2', 'L', 'D', 'L', 'D']],
#  [8, ['L', 'Rp', 'L', 'Rp', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['L', 'Rp', 'L', 'Rp', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['L', 'Rp', 'L', 'Rp', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['L', 'Rp', 'L', 'Rp', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['L', 'Rp', 'Rp', 'U2', 'L', 'D', 'L', 'D']],
#  [8, ['Lp', 'U2', 'Lp', 'D2', 'Lp', 'Dp', 'L', 'D']],
#  [8, ['Lp', 'R', 'R', 'U2', 'Lp', 'D', 'Lp', 'D']],
#  [8, ['Lp', 'R', 'Lp', 'R', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['Lp', 'R', 'Lp', 'R', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['Lp', 'R', 'Lp', 'R', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['Lp', 'R', 'Lp', 'R', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['Lp', 'Rp', 'Rp', 'U2', 'Lp', 'D', 'Lp', 'D']],
#  [8, ['Lp', 'Rp', 'Lp', 'Rp', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['Lp', 'Rp', 'Lp', 'Rp', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['Lp', 'Rp', 'Rp', 'U2', 'Lp', 'D', 'Lp', 'D']],
#  [8, ['Lp', 'Rp', 'Lp', 'Rp', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['Lp', 'Rp', 'Lp', 'Rp', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['R', 'U2', 'R', 'D2', 'R', 'D', 'R', 'Dp']],
#  [8, ['R', 'L', 'L', 'R', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['R', 'L', 'L', 'R', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['R', 'L', 'R', 'U2', 'L', 'D', 'L', 'D']],
#  [8, ['R', 'L', 'L', 'R', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['R', 'L', 'L', 'R', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['R', 'L', 'R', 'U2', 'L', 'D', 'L', 'D']],
#  [8, ['R', 'Lp', 'R', 'U2', 'Lp', 'D', 'Lp', 'D']],
#  [8, ['R', 'Lp', 'Lp', 'R', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['R', 'Lp', 'Lp', 'R', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['R', 'Lp', 'Lp', 'R', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['R', 'Lp', 'Lp', 'R', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['Rp', 'U2', 'Rp', 'D2', 'Rp', 'D', 'Rp', 'Dp']],
#  [8, ['Rp', 'L', 'L', 'Rp', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['Rp', 'L', 'L', 'Rp', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['Rp', 'L', 'L', 'Rp', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['Rp', 'L', 'L', 'Rp', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['Rp', 'L', 'Rp', 'U2', 'L', 'D', 'L', 'D']],
#  [8, ['Rp', 'Lp', 'Rp', 'U2', 'Lp', 'D', 'Lp', 'D']],
#  [8, ['Rp', 'Lp', 'Lp', 'Rp', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['Rp', 'Lp', 'Lp', 'Rp', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['Rp', 'Lp', 'Rp', 'U2', 'Lp', 'D', 'Lp', 'D']],
#  [8, ['Rp', 'Lp', 'Lp', 'Rp', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['Rp', 'Lp', 'Lp', 'Rp', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['L', 'U2', 'L', 'D2', 'L', 'Dp', 'Lp', 'D']],
#  [8, ['L', 'R', 'L', 'R', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['L', 'R', 'L', 'R', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['L', 'R', 'R', 'U2', 'L', 'D', 'L', 'D']],
#  [8, ['L', 'R', 'L', 'R', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['L', 'R', 'L', 'R', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['L', 'R', 'R', 'U2', 'L', 'D', 'L', 'D']],
#  [8, ['L', 'Rp', 'L', 'Rp', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['L', 'Rp', 'L', 'Rp', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['L', 'Rp', 'L', 'Rp', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['L', 'Rp', 'L', 'Rp', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['L', 'Rp', 'Rp', 'U2', 'L', 'D', 'L', 'D']],
#  [8, ['Lp', 'U2', 'Lp', 'D2', 'Lp', 'Dp', 'L', 'D']],
#  [8, ['Lp', 'R', 'R', 'U2', 'Lp', 'D', 'Lp', 'D']],
#  [8, ['Lp', 'R', 'Lp', 'R', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['Lp', 'R', 'Lp', 'R', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['Lp', 'R', 'Lp', 'R', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['Lp', 'R', 'Lp', 'R', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['Lp', 'Rp', 'Rp', 'U2', 'Lp', 'D', 'Lp', 'D']],
#  [8, ['Lp', 'Rp', 'Lp', 'Rp', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['Lp', 'Rp', 'Lp', 'Rp', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['Lp', 'Rp', 'Rp', 'U2', 'Lp', 'D', 'Lp', 'D']],
#  [8, ['Lp', 'Rp', 'Lp', 'Rp', 'Dp', 'R', 'R', 'Dp']],
#  [8, ['Lp', 'Rp', 'Lp', 'Rp', 'Dp', 'Rp', 'Rp', 'Dp']],
#  [8, ['U', 'Bp', 'Fp', 'Lp', 'U', 'Bp', 'R', 'Dp']],
#  [8, ['U', 'Bp', 'Fp', 'Lp', 'U', 'Bp', 'R', 'Dp']],
#  [8, ['U', 'Bp', 'Fp', 'Lp', 'U', 'Bp', 'R', 'Dp']],
#  [8, ['U', 'Bp', 'Fp', 'Lp', 'U', 'Bp', 'R', 'Dp']],
#  [8, ['U', 'Bp', 'Fp', 'Lp', 'U', 'Bp', 'R', 'Dp']],
#  [8, ['U', 'Bp', 'Fp', 'Lp', 'U', 'Bp', 'R', 'Dp']],
#  [8, ['U', 'Bp', 'Fp', 'Lp', 'U', 'Bp', 'R', 'Dp']],
#  [8, ['U', 'Bp', 'Fp', 'Lp', 'U', 'Bp', 'R', 'Dp']],
#  [8, ['U', 'Bp', 'Fp', 'Lp', 'U', 'Bp', 'R', 'Dp']],
#  [8, ['U', 'Bp', 'Fp', 'Lp', 'U', 'Bp', 'R', 'Dp']],
#  [8, ['U', 'Bp', 'Fp', 'Lp', 'U', 'Bp', 'R', 'Dp']],
#  [8, ['U', 'Bp', 'Fp', 'Lp', 'U', 'Bp', 'R', 'Dp']],
#  [9, ['D', 'L', 'Fp', 'F', 'Dp', 'Rp', 'D', 'Fp', 'D']],
#  [9, ['D', 'L', 'Fp', 'F', 'Dp', 'Rp', 'D', 'Fp', 'D']],
#  [9, ['D', 'L', 'Fp', 'Fp', 'D', 'L', 'Dp', 'F', 'D']],
#  [9, ['D', 'L', 'Fp', 'Fp', 'D', 'L', 'Dp', 'F', 'D']],
#  [9, ['D', 'L', 'Fp', 'F', 'Dp', 'Rp', 'D', 'Fp', 'D']],
#  [9, ['D', 'L', 'Fp', 'F', 'Dp', 'Rp', 'D', 'Fp', 'D']],
#  [9, ['D', 'L', 'Fp', 'Fp', 'D', 'L', 'Dp', 'F', 'D']],
#  [9, ['D', 'L', 'Fp', 'Fp', 'D', 'L', 'Dp', 'F', 'D']],
#  [9, ['U2', 'Rp', 'D', 'F', 'D', 'F', 'D', 'Rp', 'Dp']],
#  [9, ['U2', 'Rp', 'D', 'F', 'D', 'Fp', 'Dp', 'L', 'D']],
#  [9, ['U2', 'Rp', 'D', 'F', 'D', 'F', 'D', 'Rp', 'Dp']],
#  [9, ['U2', 'Rp', 'D', 'F', 'D', 'Fp', 'Dp', 'L', 'D']],
#  [9, ['Lp', 'D', 'L', 'L', 'Dp', 'Rp', 'D', 'Fp', 'D']],
#  [9, ['Lp', 'D', 'L', 'L', 'Dp', 'Rp', 'D', 'Fp', 'D']],
#  [9, ['Lp', 'D', 'L', 'L', 'Dp', 'Rp', 'D', 'Fp', 'D']],
#  [9, ['Lp', 'D', 'L', 'L', 'Dp', 'Rp', 'D', 'Fp', 'D']],
#  [9, ['Lp', 'D', 'Lp', 'Lp', 'Dp', 'Rp', 'D', 'Fp', 'D']],
#  [9, ['Lp', 'D', 'Lp', 'Lp', 'Dp', 'Rp', 'D', 'Fp', 'D']],
#  [9, ['Lp', 'D', 'Lp', 'Lp', 'Dp', 'Rp', 'D', 'Fp', 'D']],
#  [9, ['Lp', 'D', 'Lp', 'Lp', 'Dp', 'Rp', 'D', 'Fp', 'D']],
#  [9, ['Lp', 'D', 'Lp', 'Lp', 'Dp', 'Rp', 'D', 'Fp', 'D']],
#  [9, ['Lp', 'D', 'Lp', 'Lp', 'Dp', 'Rp', 'D', 'Fp', 'D']],
#  [9, ['Up', 'B', 'D2', 'Bp', 'Bp', 'R', 'D2', 'R', 'D2']],
#  [9, ['Up', 'B', 'D2', 'Bp', 'Bp', 'R', 'D2', 'R', 'D2']],
#  [9, ['Up', 'B', 'R', 'U', 'R', 'Lp', 'D', 'R', 'D']],
#  [9, ['Up', 'B', 'R', 'Up', 'Lp', 'R', 'Dp', 'Lp', 'Dp']],
#  [9, ['Up', 'B', 'Rp', 'U', 'Rp', 'Lp', 'D', 'Rp', 'D']],
#  [9, ['Up', 'B', 'Rp', 'U', 'Rp', 'Lp', 'D', 'Rp', 'D']],
#  [9, ['Up', 'B', 'Rp', 'Up', 'Lp', 'Rp', 'Dp', 'Lp', 'Dp']],
#  [9, ['Up', 'B', 'Rp', 'Up', 'Lp', 'Rp', 'Dp', 'Lp', 'Dp']],
#  [9, ['Up', 'B', 'Rp', 'U', 'Rp', 'Lp', 'D', 'Rp', 'D']],
#  [9, ['Up', 'B', 'Rp', 'U', 'Rp', 'Lp', 'D', 'Rp', 'D']],
#  [9, ['Up', 'B', 'Rp', 'Up', 'Lp', 'Rp', 'Dp', 'Lp', 'Dp']],
#  [9, ['Up', 'B', 'Rp', 'Up', 'Lp', 'Rp', 'Dp', 'Lp', 'Dp']],
#  [9, ['Up', 'B', 'D2', 'Bp', 'Bp', 'R', 'D2', 'R', 'D2']],
#  [9, ['Up', 'B', 'D2', 'Bp', 'Bp', 'R', 'D2', 'R', 'D2']],
#  [9, ['Up', 'B', 'R', 'U', 'R', 'Lp', 'D', 'R', 'D']],
#  [9, ['Up', 'B', 'R', 'Up', 'Lp', 'R', 'Dp', 'Lp', 'Dp']],
#  [9, ['Up', 'B', 'Rp', 'U', 'Rp', 'Lp', 'D', 'Rp', 'D']],
#  [9, ['Up', 'B', 'Rp', 'U', 'Rp', 'Lp', 'D', 'Rp', 'D']],
#  [9, ['Up', 'B', 'Rp', 'Up', 'Lp', 'Rp', 'Dp', 'Lp', 'Dp']],
#  [9, ['Up', 'B', 'Rp', 'Up', 'Lp', 'Rp', 'Dp', 'Lp', 'Dp']],
#  [9, ['Up', 'B', 'Rp', 'U', 'Rp', 'Lp', 'D', 'Rp', 'D']],
#  [9, ['Up', 'B', 'Rp', 'U', 'Rp', 'Lp', 'D', 'Rp', 'D']],
#  [9, ['Up', 'B', 'Rp', 'Up', 'Lp', 'Rp', 'Dp', 'Lp', 'Dp']],
#  [9, ['Up', 'B', 'Rp', 'Up', 'Lp', 'Rp', 'Dp', 'Lp', 'Dp']],
#  [9, ['Up', 'Bp', 'R', 'U', 'D2', 'R', 'Dp', 'R', 'Dp']],
#  [9, ['U2', 'Bp', 'Dp', 'Bp', 'L', 'Fp', 'Dp', 'Bp', 'D2']],
#  [9, ['U2', 'Bp', 'Dp', 'Bp', 'L', 'Fp', 'Dp', 'Bp', 'D2']],
#  [9, ['U2', 'Bp', 'L', 'Dp', 'Bp', 'Fp', 'Dp', 'Bp', 'D2']],
#  [9, ['U2', 'Bp', 'L', 'Dp', 'Bp', 'Fp', 'Dp', 'Bp', 'D2']],
#  [9, ['U2', 'Bp', 'L', 'Dp', 'Bp', 'Fp', 'Dp', 'Bp', 'D2']],
#  [9, ['U2', 'Bp', 'L', 'Dp', 'Bp', 'Fp', 'Dp', 'Bp', 'D2']],
#  [9, ['Rp', 'Rp', 'Dp', 'F', 'B', 'L', 'Dp', 'F', 'Dp']],
#  [9, ['Rp', 'Rp', 'Dp', 'F', 'B', 'L', 'Dp', 'F', 'Dp']],
#  [9, ['Rp', 'Rp', 'Dp', 'F', 'B', 'L', 'Dp', 'F', 'Dp']],
#  [9, ['Rp', 'Rp', 'Dp', 'F', 'B', 'L', 'Dp', 'F', 'Dp']],
#  [9, ['Rp', 'Rp', 'Dp', 'F', 'B', 'L', 'Dp', 'F', 'Dp']],
#  [9, ['Rp', 'Rp', 'Dp', 'F', 'B', 'L', 'Dp', 'F', 'Dp']],
#  [9, ['Rp', 'Rp', 'Dp', 'F', 'B', 'L', 'Dp', 'F', 'Dp']],
#  [9, ['Rp', 'Rp', 'Dp', 'F', 'B', 'L', 'Dp', 'F', 'Dp']],
#  [9, ['Rp', 'Rp', 'Dp', 'F', 'B', 'L', 'Dp', 'F', 'Dp']],
#  [9, ['Rp', 'Rp', 'Dp', 'F', 'B', 'L', 'Dp', 'F', 'Dp']],
#  [9, ['Rp', 'Rp', 'Dp', 'F', 'B', 'L', 'Dp', 'F', 'Dp']],
#  [9, ['Rp', 'Rp', 'Dp', 'F', 'B', 'L', 'Dp', 'F', 'Dp']],
#  [9, ['Rp', 'Rp', 'Dp', 'F', 'B', 'L', 'Dp', 'F', 'Dp']],
#  [9, ['Rp', 'Rp', 'Dp', 'F', 'B', 'L', 'Dp', 'F', 'Dp']],
#  [9, ['Rp', 'Rp', 'Dp', 'F', 'B', 'L', 'Dp', 'F', 'Dp']],
#  [9, ['Rp', 'Rp', 'Dp', 'F', 'B', 'L', 'Dp', 'F', 'Dp']],
#  [9, ['Rp', 'Rp', 'Dp', 'F', 'B', 'L', 'Dp', 'F', 'Dp']],
#  [9, ['Rp', 'Rp', 'Dp', 'F', 'B', 'L', 'Dp', 'F', 'Dp']],
#  [9, ['D2', 'Lp', 'R', 'F', 'Dp', 'F', 'D', 'Rp', 'D2']],
#  [9, ['D2', 'Lp', 'R', 'F', 'Dp', 'F', 'D', 'Rp', 'D2']],
#  [9, ['L', 'D2', 'L', 'L', 'Up', 'Fp', 'Dp', 'Fp', 'Dp']],
#  [9, ['L', 'D2', 'L', 'L', 'Up', 'Fp', 'Dp', 'Fp', 'Dp']],
#  [9, ['L', 'D2', 'Lp', 'Lp', 'Up', 'Fp', 'Dp', 'Fp', 'Dp']],
#  [9, ['L', 'D2', 'Lp', 'Lp', 'Up', 'Fp', 'Dp', 'Fp', 'Dp']],
#  [9, ['D2', 'F', 'F', 'U', 'D2', 'L', 'D2', 'L', 'Dp']],
#  [9, ['D2', 'F', 'F', 'D', 'F', 'F', 'Dp', 'Rp', 'Dp']],
#  [9, ['D2', 'F', 'F', 'D', 'F', 'F', 'Dp', 'Rp', 'Dp']],
#  [9, ['D2', 'F', 'F', 'D', 'Fp', 'Fp', 'Dp', 'Rp', 'Dp']],
#  [9, ['D2', 'F', 'F', 'D', 'Fp', 'Fp', 'Dp', 'Rp', 'Dp']],
#  [9, ['D2', 'F', 'F', 'U', 'D2', 'L', 'D2', 'L', 'Dp']],
#  [9, ['D2', 'F', 'F', 'D', 'F', 'F', 'Dp', 'Rp', 'Dp']],
#  [9, ['D2', 'F', 'F', 'D', 'F', 'F', 'Dp', 'Rp', 'Dp']],
#  [9, ['D2', 'F', 'F', 'D', 'Fp', 'Fp', 'Dp', 'Rp', 'Dp']],
#  [9, ['D2', 'F', 'F', 'D', 'Fp', 'Fp', 'Dp', 'Rp', 'Dp']],
#  [9, ['D2', 'Fp', 'Fp', 'U', 'D2', 'L', 'D2', 'L', 'Dp']],
#  [9, ['D2', 'Fp', 'Fp', 'D', 'F', 'F', 'Dp', 'Rp', 'Dp']],
#  [9, ['D2', 'Fp', 'Fp', 'D', 'F', 'F', 'Dp', 'Rp', 'Dp']],
#  [9, ['D2', 'Fp', 'Fp', 'D', 'Fp', 'Fp', 'Dp', 'Rp', 'Dp']],
#  [9, ['D2', 'Fp', 'Fp', 'D', 'Fp', 'Fp', 'Dp', 'Rp', 'Dp']],
#  [9, ['D2', 'Fp', 'Fp', 'U', 'D2', 'L', 'D2', 'L', 'Dp']],
#  [9, ['D2', 'Fp', 'Fp', 'D', 'F', 'F', 'Dp', 'Rp', 'Dp']],
#  [9, ['D2', 'Fp', 'Fp', 'D', 'F', 'F', 'Dp', 'Rp', 'Dp']],
#  [9, ['D2', 'Fp', 'Fp', 'D', 'Fp', 'Fp', 'Dp', 'Rp', 'Dp']],
#  [9, ['D2', 'Fp', 'Fp', 'D', 'Fp', 'Fp', 'Dp', 'Rp', 'Dp']],
#  [9, ['D', 'Fp', 'D', 'Fp', 'D2', 'L', 'Dp', 'F', 'D2']],
#  [9, ['D', 'Fp', 'D', 'Fp', 'D2', 'L', 'Dp', 'F', 'D2']],
#  [9, ['R', 'U2', 'Dp', 'Rp', 'Dp', 'Rp', 'D2', 'Rp', 'D2']],
#  [9, ['R', 'L', 'R', 'Dp', 'R', 'R', 'D', 'L', 'D2']],
#  [9, ['R', 'L', 'R', 'Dp', 'R', 'R', 'D', 'L', 'D2']],
#  [9, ['R', 'L', 'R', 'Dp', 'Rp', 'Rp', 'D', 'L', 'D2']],
#  [9, ['R', 'L', 'R', 'Dp', 'R', 'R', 'D', 'L', 'D2']],
#  [9, ['R', 'L', 'R', 'Dp', 'R', 'R', 'D', 'L', 'D2']],
#  [9, ['R', 'L', 'R', 'Dp', 'Rp', 'Rp', 'D', 'L', 'D2']],
#  [9, ['R', 'Lp', 'R', 'Dp', 'R', 'R', 'D', 'Lp', 'D2']],
#  [9, ['R', 'Lp', 'R', 'Dp', 'Rp', 'Rp', 'D', 'Lp', 'D2']],
#  [9, ['R', 'Lp', 'R', 'Dp', 'Rp', 'Rp', 'D', 'Lp', 'D2']],
#  [9, ['Rp', 'U2', 'Dp', 'R', 'Dp', 'R', 'D2', 'R', 'D2']],
#  [9, ['Rp', 'L', 'Rp', 'Dp', 'R', 'R', 'D', 'L', 'D2']],
#  [9, ['Rp', 'L', 'Rp', 'Dp', 'R', 'R', 'D', 'L', 'D2']],
#  [9, ['Rp', 'L', 'Rp', 'Dp', 'Rp', 'Rp', 'D', 'L', 'D2']],
#  [9, ['Rp', 'Lp', 'Rp', 'Dp', 'R', 'R', 'D', 'Lp', 'D2']],
#  [9, ['Rp', 'Lp', 'Rp', 'Dp', 'Rp', 'Rp', 'D', 'Lp', 'D2']],
#  [9, ['Rp', 'Lp', 'Rp', 'Dp', 'Rp', 'Rp', 'D', 'Lp', 'D2']],
#  [9, ['Rp', 'Lp', 'Rp', 'Dp', 'R', 'R', 'D', 'Lp', 'D2']],
#  [9, ['Rp', 'Lp', 'Rp', 'Dp', 'Rp', 'Rp', 'D', 'Lp', 'D2']],
#  [9, ['Rp', 'Lp', 'Rp', 'Dp', 'Rp', 'Rp', 'D', 'Lp', 'D2']],
#  [9, ['D', 'R', 'U2', 'R', 'D2', 'R', 'Dp', 'R', 'D']],
#  [9, ['D', 'R', 'L', 'R', 'U2', 'L', 'Dp', 'L', 'Dp']],
#  [9, ['D', 'R', 'L', 'R', 'U2', 'L', 'Dp', 'L', 'Dp']],
#  [9, ['D', 'R', 'Lp', 'R', 'U2', 'Lp', 'Dp', 'Lp', 'Dp']],
#  [9, ['D', 'Rp', 'U2', 'Rp', 'D2', 'Rp', 'Dp', 'Rp', 'D']],
#  [9, ['D', 'Rp', 'L', 'Rp', 'U2', 'L', 'Dp', 'L', 'Dp']],
#  [9, ['D', 'Rp', 'Lp', 'Rp', 'U2', 'Lp', 'Dp', 'Lp', 'Dp']],
#  [9, ['D', 'Rp', 'Lp', 'Rp', 'U2', 'Lp', 'Dp', 'Lp', 'Dp']],
#  [9, ['L', 'U2', 'D', 'L', 'D2', 'L', 'D', 'Lp', 'Dp']],
#  [9, ['L', 'R', 'R', 'Dp', 'R', 'R', 'D', 'L', 'D2']],
#  [9, ['L', 'R', 'R', 'Dp', 'R', 'R', 'D', 'L', 'D2']],
#  [9, ['L', 'R', 'R', 'Dp', 'Rp', 'Rp', 'D', 'L', 'D2']],
#  [9, ['L', 'R', 'R', 'Dp', 'R', 'R', 'D', 'L', 'D2']],
#  [9, ['L', 'R', 'R', 'Dp', 'R', 'R', 'D', 'L', 'D2']],
#  [9, ['L', 'R', 'R', 'Dp', 'Rp', 'Rp', 'D', 'L', 'D2']],
#  [9, ['L', 'Rp', 'Rp', 'Dp', 'R', 'R', 'D', 'L', 'D2']],
#  [9, ['L', 'Rp', 'Rp', 'Dp', 'R', 'R', 'D', 'L', 'D2']],
#  [9, ['L', 'Rp', 'Rp', 'Dp', 'Rp', 'Rp', 'D', 'L', 'D2']],
#  [9, ['L', 'D', 'R', 'R', 'U2', 'L', 'Dp', 'L', 'Dp']],
#  [9, ['L', 'D', 'R', 'R', 'U2', 'L', 'Dp', 'L', 'Dp']],
#  [9, ['L', 'D', 'Rp', 'Rp', 'U2', 'L', 'Dp', 'L', 'Dp']],
#  [9, ['Lp', 'U2', 'D', 'Lp', 'D2', 'Lp', 'D', 'L', 'Dp']],
#  [9, ['Lp', 'R', 'R', 'Dp', 'R', 'R', 'D', 'Lp', 'D2']],
#  [9, ['Lp', 'R', 'R', 'Dp', 'Rp', 'Rp', 'D', 'Lp', 'D2']],
#  [9, ['Lp', 'R', 'R', 'Dp', 'Rp', 'Rp', 'D', 'Lp', 'D2']],
#  [9, ['Lp', 'Rp', 'Rp', 'Dp', 'R', 'R', 'D', 'Lp', 'D2']],
#  [9, ['Lp', 'Rp', 'Rp', 'Dp', 'Rp', 'Rp', 'D', 'Lp', 'D2']],
#  [9, ['Lp', 'Rp', 'Rp', 'Dp', 'Rp', 'Rp', 'D', 'Lp', 'D2']],
#  [9, ['Lp', 'Rp', 'Rp', 'Dp', 'R', 'R', 'D', 'Lp', 'D2']],
#  [9, ['Lp', 'Rp', 'Rp', 'Dp', 'Rp', 'Rp', 'D', 'Lp', 'D2']],
#  [9, ['Lp', 'Rp', 'Rp', 'Dp', 'Rp', 'Rp', 'D', 'Lp', 'D2']],
#  [9, ['Lp', 'D', 'R', 'R', 'U2', 'Lp', 'Dp', 'Lp', 'Dp']],
#  [9, ['Lp', 'D', 'Rp', 'Rp', 'U2', 'Lp', 'Dp', 'Lp', 'Dp']],
#  [9, ['Lp', 'D', 'Rp', 'Rp', 'U2', 'Lp', 'Dp', 'Lp', 'Dp']],
#  [9, ['D', 'L', 'U2', 'L', 'D2', 'L', 'D', 'Lp', 'Dp']],
#  [9, ['D', 'L', 'R', 'R', 'U2', 'L', 'Dp', 'L', 'Dp']],
#  [9, ['D', 'L', 'R', 'R', 'U2', 'L', 'Dp', 'L', 'Dp']],
#  [9, ['D', 'L', 'Rp', 'Rp', 'U2', 'L', 'Dp', 'L', 'Dp']],
#  [9, ['D', 'Lp', 'U2', 'Lp', 'D2', 'Lp', 'D', 'L', 'Dp']],
#  [9, ['D', 'Lp', 'R', 'R', 'U2', 'Lp', 'Dp', 'Lp', 'Dp']],
#  [9, ['D', 'Lp', 'Rp', 'Rp', 'U2', 'Lp', 'Dp', 'Lp', 'Dp']],
#  [9, ['D', 'Lp', 'Rp', 'Rp', 'U2', 'Lp', 'Dp', 'Lp', 'Dp']],
#  [9, ['R', 'U2', 'Dp', 'Rp', 'Dp', 'Rp', 'D2', 'Rp', 'D2']],
#  [9, ['R', 'L', 'R', 'Dp', 'R', 'R', 'D', 'L', 'D2']],
#  [9, ['R', 'L', 'R', 'Dp', 'R', 'R', 'D', 'L', 'D2']],
#  [9, ['R', 'L', 'R', 'Dp', 'Rp', 'Rp', 'D', 'L', 'D2']],
#  [9, ['R', 'L', 'R', 'Dp', 'R', 'R', 'D', 'L', 'D2']],
#  [9, ['R', 'L', 'R', 'Dp', 'R', 'R', 'D', 'L', 'D2']],
#  [9, ['R', 'L', 'R', 'Dp', 'Rp', 'Rp', 'D', 'L', 'D2']],
#  [9, ['R', 'Lp', 'R', 'Dp', 'R', 'R', 'D', 'Lp', 'D2']],
#  [9, ['R', 'Lp', 'R', 'Dp', 'Rp', 'Rp', 'D', 'Lp', 'D2']],
#  [9, ['R', 'Lp', 'R', 'Dp', 'Rp', 'Rp', 'D', 'Lp', 'D2']],
#  [9, ['Rp', 'U2', 'Dp', 'R', 'Dp', 'R', 'D2', 'R', 'D2']],
#  [9, ['Rp', 'L', 'Rp', 'Dp', 'R', 'R', 'D', 'L', 'D2']],
#  [9, ['Rp', 'L', 'Rp', 'Dp', 'R', 'R', 'D', 'L', 'D2']],
#  [9, ['Rp', 'L', 'Rp', 'Dp', 'Rp', 'Rp', 'D', 'L', 'D2']],
#  [9, ['Rp', 'Lp', 'Rp', 'Dp', 'R', 'R', 'D', 'Lp', 'D2']],
#  [9, ['Rp', 'Lp', 'Rp', 'Dp', 'Rp', 'Rp', 'D', 'Lp', 'D2']],
#  [9, ['Rp', 'Lp', 'Rp', 'Dp', 'Rp', 'Rp', 'D', 'Lp', 'D2']],
#  [9, ['Rp', 'Lp', 'Rp', 'Dp', 'R', 'R', 'D', 'Lp', 'D2']],
#  [9, ['Rp', 'Lp', 'Rp', 'Dp', 'Rp', 'Rp', 'D', 'Lp', 'D2']],
#  [9, ['Rp', 'Lp', 'Rp', 'Dp', 'Rp', 'Rp', 'D', 'Lp', 'D2']],
#  [9, ['D', 'R', 'U2', 'R', 'D2', 'R', 'Dp', 'R', 'D']],
#  [9, ['D', 'R', 'L', 'R', 'U2', 'L', 'Dp', 'L', 'Dp']],
#  [9, ['D', 'R', 'L', 'R', 'U2', 'L', 'Dp', 'L', 'Dp']],
#  [9, ['D', 'R', 'Lp', 'R', 'U2', 'Lp', 'Dp', 'Lp', 'Dp']],
#  [9, ['D', 'Rp', 'U2', 'Rp', 'D2', 'Rp', 'Dp', 'Rp', 'D']],
#  [9, ['D', 'Rp', 'L', 'Rp', 'U2', 'L', 'Dp', 'L', 'Dp']],
#  [9, ['D', 'Rp', 'Lp', 'Rp', 'U2', 'Lp', 'Dp', 'Lp', 'Dp']],
#  [9, ['D', 'Rp', 'Lp', 'Rp', 'U2', 'Lp', 'Dp', 'Lp', 'Dp']],
#  [9, ['L', 'U2', 'D', 'L', 'D2', 'L', 'D', 'Lp', 'Dp']],
#  [9, ['L', 'R', 'R', 'Dp', 'R', 'R', 'D', 'L', 'D2']],
#  [9, ['L', 'R', 'R', 'Dp', 'R', 'R', 'D', 'L', 'D2']],
#  [9, ['L', 'R', 'R', 'Dp', 'Rp', 'Rp', 'D', 'L', 'D2']],
#  [9, ['L', 'R', 'R', 'Dp', 'R', 'R', 'D', 'L', 'D2']],
#  [9, ['L', 'R', 'R', 'Dp', 'R', 'R', 'D', 'L', 'D2']],
#  [9, ['L', 'R', 'R', 'Dp', 'Rp', 'Rp', 'D', 'L', 'D2']],
#  [9, ['L', 'Rp', 'Rp', 'Dp', 'R', 'R', 'D', 'L', 'D2']],
#  [9, ['L', 'Rp', 'Rp', 'Dp', 'R', 'R', 'D', 'L', 'D2']],
#  [9, ['L', 'Rp', 'Rp', 'Dp', 'Rp', 'Rp', 'D', 'L', 'D2']],
#  [9, ['L', 'D', 'R', 'R', 'U2', 'L', 'Dp', 'L', 'Dp']],
#  [9, ['L', 'D', 'R', 'R', 'U2', 'L', 'Dp', 'L', 'Dp']],
#  [9, ['L', 'D', 'Rp', 'Rp', 'U2', 'L', 'Dp', 'L', 'Dp']],
#  [9, ['Lp', 'U2', 'D', 'Lp', 'D2', 'Lp', 'D', 'L', 'Dp']],
#  [9, ['Lp', 'R', 'R', 'Dp', 'R', 'R', 'D', 'Lp', 'D2']],
#  [9, ['Lp', 'R', 'R', 'Dp', 'Rp', 'Rp', 'D', 'Lp', 'D2']],
#  [9, ['Lp', 'R', 'R', 'Dp', 'Rp', 'Rp', 'D', 'Lp', 'D2']],
#  [9, ['Lp', 'Rp', 'Rp', 'Dp', 'R', 'R', 'D', 'Lp', 'D2']],
#  [9, ['Lp', 'Rp', 'Rp', 'Dp', 'Rp', 'Rp', 'D', 'Lp', 'D2']],
#  [9, ['Lp', 'Rp', 'Rp', 'Dp', 'Rp', 'Rp', 'D', 'Lp', 'D2']],
#  [9, ['Lp', 'Rp', 'Rp', 'Dp', 'R', 'R', 'D', 'Lp', 'D2']],
#  [9, ['Lp', 'Rp', 'Rp', 'Dp', 'Rp', 'Rp', 'D', 'Lp', 'D2']],
#  [9, ['Lp', 'Rp', 'Rp', 'Dp', 'Rp', 'Rp', 'D', 'Lp', 'D2']],
#  [9, ['Lp', 'D', 'R', 'R', 'U2', 'Lp', 'Dp', 'Lp', 'Dp']],
#  [9, ['Lp', 'D', 'Rp', 'Rp', 'U2', 'Lp', 'Dp', 'Lp', 'Dp']],
#  [9, ['Lp', 'D', 'Rp', 'Rp', 'U2', 'Lp', 'Dp', 'Lp', 'Dp']],
#  [9, ['D', 'L', 'U2', 'L', 'D2', 'L', 'D', 'Lp', 'Dp']],
#  [9, ['D', 'L', 'R', 'R', 'U2', 'L', 'Dp', 'L', 'Dp']],
#  [9, ['D', 'L', 'R', 'R', 'U2', 'L', 'Dp', 'L', 'Dp']],
#  [9, ['D', 'L', 'Rp', 'Rp', 'U2', 'L', 'Dp', 'L', 'Dp']],
#  [9, ['D', 'Lp', 'U2', 'Lp', 'D2', 'Lp', 'D', 'L', 'Dp']],
#  [9, ['D', 'Lp', 'R', 'R', 'U2', 'Lp', 'Dp', 'Lp', 'Dp']],
#  [9, ['D', 'Lp', 'Rp', 'Rp', 'U2', 'Lp', 'Dp', 'Lp', 'Dp']],
#  [9, ['D', 'Lp', 'Rp', 'Rp', 'U2', 'Lp', 'Dp', 'Lp', 'Dp']],
#  [9, ['Up', 'B', 'Fp', 'D2', 'R', 'Fp', 'Dp', 'B', 'D2']],
#  [9, ['Up', 'B', 'Fp', 'D2', 'R', 'Fp', 'Dp', 'B', 'D2']],
#  [9, ['Up', 'B', 'Fp', 'D2', 'Fp', 'R', 'Dp', 'B', 'D2']],
#  [9, ['Up', 'B', 'Fp', 'D2', 'Fp', 'R', 'Dp', 'B', 'D2']],
#  [9, ['Up', 'B', 'Fp', 'D2', 'R', 'Fp', 'Dp', 'B', 'D2']],
#  [9, ['Up', 'B', 'Fp', 'D2', 'R', 'Fp', 'Dp', 'B', 'D2']],
#  [9, ['Up', 'B', 'Fp', 'D2', 'Fp', 'R', 'Dp', 'B', 'D2']],
#  [9, ['Up', 'B', 'Fp', 'D2', 'Fp', 'R', 'Dp', 'B', 'D2']],
#  [10, ['L', 'L', 'L', 'D2', 'Fp', 'L', 'R', 'D2', 'Lp', 'Rp']],
#  [10, ['L', 'L', 'L', 'D2', 'Fp', 'L', 'R', 'D2', 'Lp', 'Rp']],
#  [10, ['L', 'Lp', 'Lp', 'D2', 'Fp', 'L', 'R', 'D2', 'Lp', 'Rp']],
#  [10, ['L', 'Lp', 'Lp', 'D2', 'Fp', 'L', 'R', 'D2', 'Lp', 'Rp']],
#  [11, ['L', 'U', 'B', 'Dp', 'B', 'D', 'F', 'B', 'D2', 'Fp', 'Bp']],
#  [12, ['L', 'Fp', 'D', 'F', 'D2', 'Rp', 'Fp', 'F', 'B', 'D2', 'Fp', 'Bp']],
#  [12, ['L', 'Fp', 'D', 'F', 'D2', 'Rp', 'Fp', 'F', 'B', 'D2', 'Fp', 'Bp']],
#  [12, ['L', 'Fp', 'D', 'F', 'D2', 'Rp', 'Fp', 'F', 'B', 'D2', 'Fp', 'Bp']],
#  [12, ['L', 'Fp', 'D', 'F', 'D2', 'Rp', 'Fp', 'F', 'B', 'D2', 'Fp', 'Bp']],
#  [12, ['Up', 'Bp', 'D2', 'R', 'B', 'B', 'Lp', 'L', 'R', 'D2', 'Lp', 'Rp']],
#  [12, ['Up', 'Bp', 'D2', 'R', 'B', 'B', 'Lp', 'L', 'R', 'D2', 'Lp', 'Rp']],
#  [12, ['Up', 'Bp', 'D2', 'R', 'Bp', 'Bp', 'Lp', 'L', 'R', 'D2', 'Lp', 'Rp']],
#  [12, ['Up', 'Bp', 'D2', 'R', 'Bp', 'Bp', 'Lp', 'L', 'R', 'D2', 'Lp', 'Rp']],
#  [12, ['Up', 'Bp', 'D2', 'R', 'B', 'B', 'Lp', 'L', 'R', 'D2', 'Lp', 'Rp']],
#  [12, ['Up', 'Bp', 'D2', 'R', 'B', 'B', 'Lp', 'L', 'R', 'D2', 'Lp', 'Rp']],
#  [12, ['Up', 'Bp', 'D2', 'R', 'Bp', 'Bp', 'Lp', 'L', 'R', 'D2', 'Lp', 'Rp']],
#  [12, ['Up', 'Bp', 'D2', 'R', 'Bp', 'Bp', 'Lp', 'L', 'R', 'D2', 'Lp', 'Rp']],
#  [12, ['L', 'L', 'Lp', 'L', 'L', 'D2', 'Fp', 'L', 'R', 'D2', 'Lp', 'Rp']],
#  [12, ['L', 'L', 'Lp', 'L', 'L', 'D2', 'Fp', 'L', 'R', 'D2', 'Lp', 'Rp']],
#  [12, ['L', 'L', 'Lp', 'Lp', 'Lp', 'D2', 'Fp', 'L', 'R', 'D2', 'Lp', 'Rp']],
#  [12, ['L', 'L', 'Lp', 'Lp', 'Lp', 'D2', 'Fp', 'L', 'R', 'D2', 'Lp', 'Rp']],
#  [12, ['L', 'Lp', 'L', 'L', 'L', 'D2', 'Fp', 'L', 'R', 'D2', 'Lp', 'Rp']],
#  [12, ['L', 'Lp', 'L', 'L', 'L', 'D2', 'Fp', 'L', 'R', 'D2', 'Lp', 'Rp']],
#  [12, ['L', 'Lp', 'L', 'Lp', 'Lp', 'D2', 'Fp', 'L', 'R', 'D2', 'Lp', 'Rp']],
#  [12, ['L', 'Lp', 'L', 'Lp', 'Lp', 'D2', 'Fp', 'L', 'R', 'D2', 'Lp', 'Rp']],
#  [13,
#   ['L', 'D', 'Fp', 'Dp', 'F', 'Rp', 'D2', 'Fp', 'L', 'R', 'D2', 'Lp', 'Rp']],
#  [13,
#   ['L', 'D', 'Fp', 'Dp', 'F', 'Rp', 'D2', 'Fp', 'L', 'R', 'D2', 'Lp', 'Rp']],
#  [13,
#   ['L', 'D', 'Fp', 'Dp', 'F', 'Rp', 'D2', 'Fp', 'L', 'R', 'D2', 'Lp', 'Rp']],
#  [13,
#   ['L', 'D', 'Fp', 'Dp', 'F', 'Rp', 'D2', 'Fp', 'L', 'R', 'D2', 'Lp', 'Rp']],
#  [13, ['Rp', 'F', 'Rp', 'D', 'B', 'F', 'D2', 'R', 'F', 'B', 'D2', 'Fp', 'Bp']],
#  [13, ['Rp', 'F', 'Rp', 'D', 'B', 'F', 'D2', 'R', 'F', 'B', 'D2', 'Fp', 'Bp']],
#  [13, ['Rp', 'F', 'Rp', 'D', 'B', 'F', 'D2', 'R', 'F', 'B', 'D2', 'Fp', 'Bp']],
#  [13, ['Rp', 'F', 'Rp', 'D', 'B', 'F', 'D2', 'R', 'F', 'B', 'D2', 'Fp', 'Bp']],
#  [13, ['Rp', 'F', 'Rp', 'D', 'B', 'F', 'D2', 'R', 'F', 'B', 'D2', 'Fp', 'Bp']],
#  [13, ['Rp', 'F', 'Rp', 'D', 'B', 'F', 'D2', 'R', 'F', 'B', 'D2', 'Fp', 'Bp']],
#  [13, ['Rp', 'F', 'Rp', 'D', 'B', 'F', 'D2', 'R', 'F', 'B', 'D2', 'Fp', 'Bp']],
#  [13, ['Rp', 'F', 'Rp', 'D', 'B', 'F', 'D2', 'R', 'F', 'B', 'D2', 'Fp', 'Bp']],
#  [13, ['Rp', 'F', 'Rp', 'D', 'B', 'F', 'D2', 'R', 'F', 'B', 'D2', 'Fp', 'Bp']],
#  [13, ['Rp', 'F', 'Rp', 'D', 'B', 'F', 'D2', 'R', 'F', 'B', 'D2', 'Fp', 'Bp']],
#  [13, ['Rp', 'F', 'Rp', 'D', 'B', 'F', 'D2', 'R', 'F', 'B', 'D2', 'Fp', 'Bp']],
#  [13, ['Rp', 'F', 'Rp', 'D', 'B', 'F', 'D2', 'R', 'F', 'B', 'D2', 'Fp', 'Bp']],
#  [13, ['L', 'L', 'Lp', 'U', 'B', 'Dp', 'B', 'Dp', 'L', 'R', 'D2', 'Lp', 'Rp']],
#  [13, ['L', 'Lp', 'L', 'U', 'B', 'Dp', 'B', 'D', 'F', 'B', 'D2', 'Fp', 'Bp']],
#  [13,
#   ['R', 'U2', 'Dp', 'Rp', 'D', 'Rp', 'D2', 'Rp', 'F', 'B', 'D2', 'Fp', 'Bp']],
#  [13,
#   ['Rp', 'U2', 'Dp', 'R', 'D', 'R', 'D2', 'R', 'F', 'B', 'D2', 'Fp', 'Bp']],
#  [13,
#   ['R', 'U2', 'Dp', 'Rp', 'D', 'Rp', 'D2', 'Rp', 'F', 'B', 'D2', 'Fp', 'Bp']],
#  [13,
#   ['Rp', 'U2', 'Dp', 'R', 'D', 'R', 'D2', 'R', 'F', 'B', 'D2', 'Fp', 'Bp']],
#  [14,
#   ['D',
#    'F',
#    'D',
#    'F',
#    'Dp',
#    'Fp',
#    'Dp',
#    'Rp',
#    'D',
#    'L',
#    'R',
#    'D2',
#    'Lp',
#    'Rp']]]

# %%
k=[]
for i in sorted_solns:
    if i[0] <= 8:
        k.append(i)

k

# %%
import matplotlib.pyplot as plt


plt.hist([x[0] for x in solns])
