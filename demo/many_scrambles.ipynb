# %%
from cube import generate_random_scramble, iterate_through_scrambles_for_testing
import random

# %%
random.seed(103195)

# %%
many_scrambles = []
for i in range(10):
    many_scrambles.append(generate_random_scramble(num_moves=20))

# %%
iterate_through_scrambles_for_testing(many_scrambles)

# %%
# next step is to solve the above, and comrpess, and visualize before and afyer, and confirm all solved
